# %%
import pandas as pd
import numpy as np
from copy import deepcopy
from sklearn import neighbors
from sklearn import preprocessing

# %% [markdown]
# Import Data

# %%
alltrain=pd.read_csv("train.csv",index_col=0,header=0)
alltest=pd.read_csv("test.csv",index_col=0,header=0)

# %%
alltrain.head(5)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
alltest['SalePrice'] = np.NaN
alltest.head(5)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1461         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 1462         Lvl    AllPub    Corner  ...        0    NaN    NaN        Gar2
# 1463         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 1464         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1465         HLS    AllPub    Inside  ...        0    NaN    NaN         NaN
#
# ...

# %%
alldata = alltrain.append(alltest)
alldata
# Out:
# C:\Users\14128\AppData\Local\Temp\ipykernel_6856\3577567064.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   alldata = alltrain.append(alltest)
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2917          20       RL        160.0    20000   Pave   NaN      Reg
# ...

# %% [markdown]
# Normalization Data

# %%
alldata.dtypes
num_data = alldata.select_dtypes(exclude=object)
numerical = num_data.columns[0:36]
string_data = alldata.select_dtypes(include=object)
categorical = string_data.columns
for column in numerical:
    alldata[column]=((alldata[column]-alldata[column].min())/(alldata[column].max()-alldata[column].min()))*10

# %% [markdown]
# KNN fill NaN values

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

# %%
alldata[categorical] = alldata[categorical].apply(lambda series: pd.Series(
        LabelEncoder().fit_transform(series[series.notnull()]),
        index=series[series.notnull()].index
    ))
print(alldata)
imp_num = IterativeImputer(estimator=RandomForestRegressor(),
                               initial_strategy='mean',
                               max_iter=1, random_state=0)
imp_cat = IterativeImputer(estimator=RandomForestClassifier(), 
                               initial_strategy='most_frequent',
                               max_iter=1, random_state=0)
alldata[numerical] = imp_num.fit_transform(alldata[numerical])
alldata[categorical] = imp_cat.fit_transform(alldata[categorical])
# Out:
#       MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# Id
# 1       2.352941       3.0     1.506849  0.334198       1    NaN         3
# 2       0.000000       3.0     2.020548  0.387950       1    NaN         3
# 3       2.352941       3.0     1.609589  0.465073       1    NaN         0
# 4       2.941176       3.0     1.335616  0.385613       1    NaN         0
# 5       2.352941       3.0     2.157534  0.605763       1    NaN         0
# ...          ...       ...          ...       ...     ...    ...       ...
# 2915    8.235294       4.0     0.000000  0.029727       1    NaN         3
# 2916    8.235294       4.0     0.000000  0.027764       1    NaN         3
# 2917    0.000000       3.0     4.760274  0.874056       1    NaN         3
# 2918    3.823529       3.0     1.404110  0.427259       1    NaN         3
# 2919    2.352941       3.0     1.815068  0.389212       1    NaN         3
#
# ...

# %%
alldata
# Out:
#       MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# Id
# 1       2.352941       3.0     1.506849  0.334198     1.0    1.0       3.0
# 2       0.000000       3.0     2.020548  0.387950     1.0    0.0       3.0
# 3       2.352941       3.0     1.609589  0.465073     1.0    1.0       0.0
# 4       2.941176       3.0     1.335616  0.385613     1.0    0.0       0.0
# 5       2.352941       3.0     2.157534  0.605763     1.0    1.0       0.0
# ...          ...       ...          ...       ...     ...    ...       ...
# 2915    8.235294       4.0     0.000000  0.029727     1.0    0.0       3.0
# 2916    8.235294       4.0     0.000000  0.027764     1.0    0.0       3.0
# 2917    0.000000       3.0     4.760274  0.874056     1.0    0.0       3.0
# 2918    3.823529       3.0     1.404110  0.427259     1.0    0.0       3.0
# 2919    2.352941       3.0     1.815068  0.389212     1.0    0.0       3.0
#
# ...

# %% [markdown]
# Mapping Category Columns

# %%
alldata.to_csv("prepossess_data.csv")

# %%
alltrain.index
prepossess_train_real = alldata.drop(alltest.index)

prepossess_train_real
prepossess_train=prepossess_train_real.sample(frac=0.8,random_state=200)
prepossess_valid=prepossess_train_real.drop(prepossess_train.index)
prepossess_train.to_csv("prepossess_train.csv")
prepossess_valid.to_csv("prepossess_valid.csv")

# %%
prepossess_test = alldata.drop(alltrain.index)
prepossess_test
prepossess_test.to_csv("prepossess_test.csv")
